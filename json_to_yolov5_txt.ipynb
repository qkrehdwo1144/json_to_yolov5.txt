# %% [markdown]
# <a href="https://colab.research.google.com/github/qkrehdwo1144/json_to_yolov5.txt/blob/main/json_to_yolov5_txt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-
import cv2
import numpy as np
import json
import yaml
import os
from pathlib import Path
from google.colab import files
from google.colab.patches import cv2_imshow
from google.colab import drive

# 기존 함수들은 그대로 유지 (read_json_file, convert_bbox_to_yolo, create_yolo_yaml, create_yolo_txt, visualize_traffic_lights)
def read_json_file(json_path):
    """JSON 파일을 읽어서 데이터를 반환합니다."""
    with open(json_path, 'r', encoding='utf-8') as f:
        data = json.load(f)
    return data

def convert_bbox_to_yolo(box, image_width, image_height):
    """바운딩 박스 좌표를 YOLO 형식으로 변환합니다."""
    x1, y1, x2, y2 = map(int, box)

    # YOLO 형식: <class> <x_center> <y_center> <width> <height>
    x_center = (x1 + x2) / (2 * image_width)
    y_center = (y1 + y2) / (2 * image_height)
    width = (x2 - x1) / image_width
    height = (y2 - y1) / image_height

    return [x_center, y_center, width, height]

def create_yolo_yaml(dataset_path, class_names):
    yaml_content = {
        'path': dataset_path,
        'train': 'images/train',
        'val': 'images/val',
        'test': 'images/test',
        'nc': len(class_names),
        'names': class_names
    }
    with open('traffic_light_dataset.yaml', 'w', encoding='utf-8') as f:
        yaml.dump(yaml_content, f, sort_keys=False, allow_unicode=True)

def create_yolo_txt(image_path, annotations, output_dir):
    """YOLO 형식의 레이블 텍스트 파일을 생성합니다."""
    image = cv2.imread(image_path)
    height, width = image.shape[:2]

    # 이미지 파일명과 동일한 텍스트 파일 생성
    base_name = Path(image_path).stem
    txt_path = os.path.join(output_dir, f"{base_name}.txt")

    with open(txt_path, 'w', encoding='utf-8') as f:
        for anno in annotations:
            if anno.get('class') == 'traffic_light':
                # 신호등 상태에 따른 클래스 인덱스 결정
                attributes = anno['attribute'][0]
                class_idx = 0  # 기본값

                # 신호 상태에 따른 클래스 분류 (예시)
                if attributes['red'] == 'on':
                    class_idx = 0  # 적색
                elif attributes['green'] == 'on':
                    class_idx = 1  # 녹색
                elif attributes['yellow'] == 'on':
                    class_idx = 2  # 황색
                elif attributes['left_arrow'] == 'on':
                    class_idx = 3  # 좌회전

                # YOLO 형식으로 좌표 변환
                yolo_bbox = convert_bbox_to_yolo(anno['box'], width, height)

                # class_idx x_center y_center width height 형식으로 저장
                f.write(f"{class_idx} {' '.join(map(str, yolo_bbox))}\n")

def visualize_traffic_lights(image_path, annotations):
    image = cv2.imread(image_path)

    for anno in annotations:
        if anno.get('class') == 'traffic_light':
            box = anno['box']
            x1, y1, x2, y2 = map(int, box)

            attributes = anno['attribute'][0]
            status = []
            if attributes['red'] == 'on':
                status.append('RED')
            if attributes['yellow'] == 'on':
                status.append('YELLOW')
            if attributes['green'] == 'on':
                status.append('GREEN')
            if attributes['left_arrow'] == 'on':
                status.append('←')
            if attributes['left_arrow'] == 'on' and attributes['green'] == 'on':
                status.append('↑←')
            if attributes['others_arrow'] == 'on':
                status.append('↔')
            if attributes['x_light'] == 'on':
                status.append('X')

            status_text = '+'.join(status) if status else 'OFF'

            cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)
            cv2.putText(image, status_text, (x1, y1-10),
                       cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

            light_type = anno.get('type', 'unknown')
            light_count = anno.get('light_count', '?')
            info_text = f"Type: {light_type} ({light_count})"
            cv2.putText(image, info_text, (x1, y2+20),
                       cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

    return image

def main():
    # Google Drive 마운트
    drive.mount('/content/drive')

    # 경로 설정
    json_dir = '/content/drive/MyDrive/json'  # JSON 파일들이 있는 디렉토리
    image_dir = '/content/drive/MyDrive/jpg'  # 이미지 파일들이 있는 디렉토리
    output_dir = '/content/drive/MyDrive/labels'  # YOLO 형식 레이블 저장 디렉토리
    visualization_dir = '/content/drive/MyDrive/output_jpg'  # 시각화 결과 저장 디렉토리

    # 출력 디렉토리 생성
    os.makedirs(output_dir, exist_ok=True)
    os.makedirs(visualization_dir, exist_ok=True)

    # JSON 파일 리스트 가져오기
    json_files = [f for f in os.listdir(json_dir) if f.endswith('.json')]

    # YOLO 데이터셋 설정
    class_names = ['red_light', 'green_light', 'yellow_light', 'left_arrow', 'straight_left_arrow']
    dataset_path = './dataset'  # 데이터셋 루트 경로

    # YAML 파일 생성
    create_yolo_yaml(dataset_path, class_names)

    for json_file in json_files:
        base_name = os.path.splitext(json_file)[0]
        image_file = f"{base_name}.jpg"

        json_path = os.path.join(json_dir, json_file)
        image_path = os.path.join(image_dir, image_file)

        if os.path.exists(image_path):
            # JSON 파일 읽기
            data = read_json_file(json_path)
            traffic_lights = [anno for anno in data['annotation']
                             if anno['class'] == 'traffic_light']

            # YOLO 형식의 레이블 파일 생성
            create_yolo_txt(image_path, traffic_lights, output_dir)

            # 시각화 실행
            result_image = visualize_traffic_lights(image_path, traffic_lights)

            # 시각화 결과 저장
            result_path = os.path.join(visualization_dir, f"{base_name}_visualized.jpg")
            cv2.imwrite(result_path, result_image)

            print(f"처리 완료: {json_file} 및 {image_file}")
            print(f"시각화 결과: {result_path}")
        else:
            print(f"이미지 파일을 찾을 수 없습니다: {image_file}")

    print(f"YOLO 형식 레이블이 {output_dir} 디렉토리에 생성되었습니다.")
    print(f"시각화 결과가 {visualization_dir} 디렉토리에 저장되었습니다.")
    print("YAML 파일이 생성되었습니다: traffic_light_dataset.yaml")

if __name__ == "__main__":
    main()
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 시각화 결과: /content/drive/MyDrive/output_jpg/13856469_visualized.jpg
# 처리 완료: 13856390.json 및 13856390.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13856390_visualized.jpg
# 처리 완료: 13908935.json 및 13908935.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13908935_visualized.jpg
# 처리 완료: 13986576.json 및 13986576.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13986576_visualized.jpg
# 처리 완료: 13700642.json 및 13700642.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13700642_visualized.jpg
# 처리 완료: 13986590.json 및 13986590.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13986590_visualized.jpg
# 처리 완료: 13826969.json 및 13826969.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13826969_visualized.jpg
# 처리 완료: 13732878.json 및 13732878.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13732878_visualized.jpg
# 처리 완료: 13672932.json 및 13672932.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13672932_visualized.jpg
# 처리 완료: 13815217.json 및 13815217.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13815217_visualized.jpg
# 처리 완료: 13997457.json 및 13997457.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13997457_visualized.jpg
# 처리 완료: 13815213.json 및 13815213.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13815213_visualized.jpg
# 처리 완료: 13856482.json 및 13856482.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13856482_visualized.jpg
# 처리 완료: 13672105.json 및 13672105.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13672105_visualized.jpg
# 처리 완료: 13978159.json 및 13978159.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13978159_visualized.jpg
# 처리 완료: 13738034.json 및 13738034.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13738034_visualized.jpg
# 처리 완료: 13981045.json 및 13981045.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13981045_visualized.jpg
# 처리 완료: 13688052.json 및 13688052.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13688052_visualized.jpg
# 처리 완료: 13720145.json 및 13720145.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13720145_visualized.jpg
# 처리 완료: 13838881.json 및 13838881.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13838881_visualized.jpg
# 처리 완료: 13700778.json 및 13700778.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13700778_visualized.jpg
# 처리 완료: 13760866.json 및 13760866.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13760866_visualized.jpg
# 처리 완료: 13908483.json 및 13908483.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13908483_visualized.jpg
# 처리 완료: 13688179.json 및 13688179.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13688179_visualized.jpg
# 처리 완료: 13720234.json 및 13720234.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13720234_visualized.jpg
# 처리 완료: 13982501.json 및 13982501.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13982501_visualized.jpg
# 처리 완료: 13818885.json 및 13818885.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13818885_visualized.jpg
# 처리 완료: 13737383.json 및 13737383.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13737383_visualized.jpg
# 처리 완료: 13732753.json 및 13732753.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13732753_visualized.jpg
# 처리 완료: 13700641.json 및 13700641.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13700641_visualized.jpg
# 처리 완료: 13784525.json 및 13784525.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13784525_visualized.jpg
# 처리 완료: 13658670.json 및 13658670.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13658670_visualized.jpg
# 처리 완료: 13647864.json 및 13647864.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13647864_visualized.jpg
# 처리 완료: 13735366.json 및 13735366.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13735366_visualized.jpg
# 처리 완료: 13735134.json 및 13735134.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13735134_visualized.jpg
# 처리 완료: 13853514.json 및 13853514.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13853514_visualized.jpg
# 처리 완료: 13952698.json 및 13952698.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13952698_visualized.jpg
# 처리 완료: 13733118.json 및 13733118.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13733118_visualized.jpg
# 처리 완료: 13909847.json 및 13909847.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13909847_visualized.jpg
# 처리 완료: 13826551.json 및 13826551.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13826551_visualized.jpg
# 처리 완료: 13918396.json 및 13918396.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13918396_visualized.jpg
# 처리 완료: 13868475.json 및 13868475.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13868475_visualized.jpg
# 처리 완료: 13838885.json 및 13838885.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13838885_visualized.jpg
# 처리 완료: 13868350.json 및 13868350.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13868350_visualized.jpg
# 처리 완료: 13945864.json 및 13945864.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13945864_visualized.jpg
# 처리 완료: 13746245.json 및 13746245.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13746245_visualized.jpg
# 처리 완료: 13985517.json 및 13985517.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13985517_visualized.jpg
# 처리 완료: 13985518.json 및 13985518.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13985518_visualized.jpg
# 처리 완료: 13750841.json 및 13750841.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13750841_visualized.jpg
# 처리 완료: 13916897.json 및 13916897.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13916897_visualized.jpg
# 처리 완료: 13945869.json 및 13945869.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13945869_visualized.jpg
# 처리 완료: 13985519.json 및 13985519.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13985519_visualized.jpg
# 처리 완료: 13716201.json 및 13716201.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13716201_visualized.jpg
# 처리 완료: 13692438.json 및 13692438.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13692438_visualized.jpg
# 처리 완료: 13818907.json 및 13818907.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13818907_visualized.jpg
# 처리 완료: 13647685.json 및 13647685.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13647685_visualized.jpg
# 처리 완료: 13853500.json 및 13853500.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13853500_visualized.jpg
# 처리 완료: 13737409.json 및 13737409.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13737409_visualized.jpg
# 처리 완료: 13827351.json 및 13827351.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13827351_visualized.jpg
# 처리 완료: 13908577.json 및 13908577.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13908577_visualized.jpg
# 처리 완료: 13868522.json 및 13868522.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13868522_visualized.jpg
# 처리 완료: 13738017.json 및 13738017.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13738017_visualized.jpg
# 처리 완료: 13676496.json 및 13676496.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13676496_visualized.jpg
# 처리 완료: 13819050.json 및 13819050.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13819050_visualized.jpg
# 처리 완료: 13950024.json 및 13950024.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13950024_visualized.jpg
# 처리 완료: 13676294.json 및 13676294.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13676294_visualized.jpg
# 처리 완료: 13976205.json 및 13976205.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13976205_visualized.jpg
# 처리 완료: 13868462.json 및 13868462.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13868462_visualized.jpg
# 처리 완료: 13749829.json 및 13749829.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13749829_visualized.jpg
# 처리 완료: 13813836.json 및 13813836.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13813836_visualized.jpg
# 처리 완료: 13846972.json 및 13846972.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13846972_visualized.jpg
# 처리 완료: 13758951.json 및 13758951.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13758951_visualized.jpg
# 처리 완료: 13840267.json 및 13840267.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13840267_visualized.jpg
# 처리 완료: 13720237.json 및 13720237.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13720237_visualized.jpg
# 처리 완료: 13676485.json 및 13676485.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13676485_visualized.jpg
# 처리 완료: 13815246.json 및 13815246.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13815246_visualized.jpg
# 처리 완료: 13735113.json 및 13735113.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13735113_visualized.jpg
# 처리 완료: 13679862.json 및 13679862.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13679862_visualized.jpg
# 처리 완료: 13720242.json 및 13720242.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13720242_visualized.jpg
# 처리 완료: 13819272.json 및 13819272.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13819272_visualized.jpg
# 처리 완료: 13738023.json 및 13738023.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13738023_visualized.jpg
# 처리 완료: 13700277.json 및 13700277.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13700277_visualized.jpg
# 처리 완료: 13687803.json 및 13687803.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13687803_visualized.jpg
# 처리 완료: 13737386.json 및 13737386.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13737386_visualized.jpg
# 처리 완료: 13819056.json 및 13819056.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13819056_visualized.jpg
# 처리 완료: 13746121.json 및 13746121.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13746121_visualized.jpg
# 처리 완료: 13840243.json 및 13840243.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13840243_visualized.jpg
# 처리 완료: 13658679.json 및 13658679.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13658679_visualized.jpg
# 처리 완료: 13846956.json 및 13846956.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13846956_visualized.jpg
# 처리 완료: 13647576.json 및 13647576.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13647576_visualized.jpg
# 처리 완료: 13849673.json 및 13849673.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13849673_visualized.jpg
# 처리 완료: 13931749.json 및 13931749.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13931749_visualized.jpg
# 처리 완료: 13879371.json 및 13879371.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13879371_visualized.jpg
# 처리 완료: 13818892.json 및 13818892.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13818892_visualized.jpg
# 처리 완료: 13784840.json 및 13784840.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13784840_visualized.jpg
# 처리 완료: 13950125.json 및 13950125.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13950125_visualized.jpg
# 처리 완료: 13931740.json 및 13931740.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13931740_visualized.jpg
# 처리 완료: 13805621.json 및 13805621.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13805621_visualized.jpg
# 처리 완료: 13916907.json 및 13916907.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13916907_visualized.jpg
# 처리 완료: 13738022.json 및 13738022.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13738022_visualized.jpg
# 처리 완료: 13840262.json 및 13840262.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13840262_visualized.jpg
# 처리 완료: 13846963.json 및 13846963.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13846963_visualized.jpg
# 처리 완료: 13688194.json 및 13688194.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13688194_visualized.jpg
# 처리 완료: 13738025.json 및 13738025.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13738025_visualized.jpg
# 처리 완료: 13784862.json 및 13784862.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13784862_visualized.jpg
# 처리 완료: 13851419.json 및 13851419.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13851419_visualized.jpg
# 처리 완료: 13679844.json 및 13679844.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13679844_visualized.jpg
# 처리 완료: 13737400.json 및 13737400.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13737400_visualized.jpg
# 처리 완료: 13850744.json 및 13850744.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13850744_visualized.jpg
# 처리 완료: 13676474.json 및 13676474.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13676474_visualized.jpg
# 처리 완료: 13850961.json 및 13850961.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13850961_visualized.jpg
# 처리 완료: 13680290.json 및 13680290.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13680290_visualized.jpg
# 처리 완료: 13700278.json 및 13700278.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13700278_visualized.jpg
# 처리 완료: 13819059.json 및 13819059.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13819059_visualized.jpg
# 처리 완료: 13735376.json 및 13735376.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13735376_visualized.jpg
# 처리 완료: 13658746.json 및 13658746.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13658746_visualized.jpg
# 처리 완료: 13668152.json 및 13668152.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13668152_visualized.jpg
# 처리 완료: 13985548.json 및 13985548.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13985548_visualized.jpg
# 처리 완료: 13813686.json 및 13813686.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13813686_visualized.jpg
# 처리 완료: 13687190.json 및 13687190.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13687190_visualized.jpg
# 처리 완료: 13879412.json 및 13879412.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13879412_visualized.jpg
# 처리 완료: 13672065.json 및 13672065.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13672065_visualized.jpg
# 처리 완료: 13868521.json 및 13868521.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13868521_visualized.jpg
# 처리 완료: 13853506.json 및 13853506.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13853506_visualized.jpg
# 처리 완료: 13955396.json 및 13955396.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13955396_visualized.jpg
# 처리 완료: 13818708.json 및 13818708.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13818708_visualized.jpg
# 처리 완료: 13849638.json 및 13849638.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13849638_visualized.jpg
# 처리 완료: 13919288.json 및 13919288.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13919288_visualized.jpg
# 처리 완료: 13737406.json 및 13737406.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13737406_visualized.jpg
# 처리 완료: 13738026.json 및 13738026.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13738026_visualized.jpg
# 처리 완료: 13819277.json 및 13819277.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13819277_visualized.jpg
# 처리 완료: 13737394.json 및 13737394.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13737394_visualized.jpg
# 처리 완료: 13815233.json 및 13815233.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13815233_visualized.jpg
# 처리 완료: 13672093.json 및 13672093.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13672093_visualized.jpg
# 처리 완료: 13815235.json 및 13815235.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13815235_visualized.jpg
# 처리 완료: 13676475.json 및 13676475.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13676475_visualized.jpg
# 처리 완료: 13676110.json 및 13676110.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13676110_visualized.jpg
# 처리 완료: 13738024.json 및 13738024.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13738024_visualized.jpg
# 처리 완료: 13849615.json 및 13849615.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13849615_visualized.jpg
# 처리 완료: 13720240.json 및 13720240.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13720240_visualized.jpg
# 처리 완료: 13850755.json 및 13850755.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13850755_visualized.jpg
# 처리 완료: 13737390.json 및 13737390.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13737390_visualized.jpg
# 처리 완료: 13687194.json 및 13687194.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13687194_visualized.jpg
# 처리 완료: 13840231.json 및 13840231.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13840231_visualized.jpg
# 처리 완료: 13931757.json 및 13931757.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13931757_visualized.jpg
# 처리 완료: 13827354.json 및 13827354.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13827354_visualized.jpg
# 처리 완료: 13849688.json 및 13849688.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13849688_visualized.jpg
# 처리 완료: 13738049.json 및 13738049.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13738049_visualized.jpg
# 처리 완료: 13737220.json 및 13737220.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13737220_visualized.jpg
# 처리 완료: 13868480.json 및 13868480.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13868480_visualized.jpg
# 처리 완료: 13840334.json 및 13840334.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13840334_visualized.jpg
# 처리 완료: 13672085.json 및 13672085.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13672085_visualized.jpg
# 처리 완료: 13784815.json 및 13784815.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13784815_visualized.jpg
# 처리 완료: 13815214.json 및 13815214.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13815214_visualized.jpg
# 처리 완료: 13687187.json 및 13687187.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13687187_visualized.jpg
# 처리 완료: 13850963.json 및 13850963.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13850963_visualized.jpg
# 처리 완료: 13819066.json 및 13819066.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13819066_visualized.jpg
# 처리 완료: 13818897.json 및 13818897.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13818897_visualized.jpg
# 처리 완료: 13866539.json 및 13866539.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13866539_visualized.jpg
# 처리 완료: 13647692.json 및 13647692.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13647692_visualized.jpg
# 처리 완료: 13952691.json 및 13952691.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13952691_visualized.jpg
# 처리 완료: 13846970.json 및 13846970.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13846970_visualized.jpg
# 처리 완료: 13676124.json 및 13676124.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13676124_visualized.jpg
# 처리 완료: 13819064.json 및 13819064.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13819064_visualized.jpg
# 처리 완료: 13849641.json 및 13849641.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13849641_visualized.jpg
# 처리 완료: 13815164.json 및 13815164.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13815164_visualized.jpg
# 처리 완료: 13742597.json 및 13742597.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13742597_visualized.jpg
# 처리 완료: 13738016.json 및 13738016.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13738016_visualized.jpg
# 처리 완료: 13866639.json 및 13866639.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13866639_visualized.jpg
# 처리 완료: 13868487.json 및 13868487.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13868487_visualized.jpg
# 처리 완료: 13813749.json 및 13813749.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13813749_visualized.jpg
# 처리 완료: 13840266.json 및 13840266.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13840266_visualized.jpg
# 처리 완료: 13918047.json 및 13918047.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13918047_visualized.jpg
# 처리 완료: 13849707.json 및 13849707.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13849707_visualized.jpg
# 처리 완료: 13710530.json 및 13710530.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13710530_visualized.jpg
# 처리 완료: 13849705.json 및 13849705.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13849705_visualized.jpg
# 처리 완료: 13879358.json 및 13879358.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13879358_visualized.jpg
# 처리 완료: 13732762.json 및 13732762.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13732762_visualized.jpg
# 처리 완료: 13976105.json 및 13976105.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13976105_visualized.jpg
# 처리 완료: 13849631.json 및 13849631.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13849631_visualized.jpg
# 처리 완료: 13950066.json 및 13950066.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13950066_visualized.jpg
# 처리 완료: 13850956.json 및 13850956.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13850956_visualized.jpg
# 처리 완료: 13749840.json 및 13749840.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13749840_visualized.jpg
# 처리 완료: 13676470.json 및 13676470.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13676470_visualized.jpg
# 처리 완료: 13868440.json 및 13868440.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13868440_visualized.jpg
# 처리 완료: 13989624.json 및 13989624.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13989624_visualized.jpg
# 처리 완료: 13849703.json 및 13849703.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13849703_visualized.jpg
# 처리 완료: 13735370.json 및 13735370.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13735370_visualized.jpg
# 처리 완료: 13676117.json 및 13676117.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13676117_visualized.jpg
# 처리 완료: 13676467.json 및 13676467.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13676467_visualized.jpg
# 처리 완료: 13916901.json 및 13916901.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13916901_visualized.jpg
# 처리 완료: 13692580.json 및 13692580.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13692580_visualized.jpg
# 처리 완료: 13737395.json 및 13737395.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13737395_visualized.jpg
# 처리 완료: 13676461.json 및 13676461.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13676461_visualized.jpg
# 처리 완료: 13679861.json 및 13679861.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13679861_visualized.jpg
# 처리 완료: 13918055.json 및 13918055.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13918055_visualized.jpg
# 처리 완료: 13784816.json 및 13784816.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13784816_visualized.jpg
# 처리 완료: 13855065.json 및 13855065.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13855065_visualized.jpg
# 처리 완료: 13918401.json 및 13918401.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13918401_visualized.jpg
# 처리 완료: 13819058.json 및 13819058.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13819058_visualized.jpg
# 처리 완료: 13737393.json 및 13737393.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13737393_visualized.jpg
# 처리 완료: 13879400.json 및 13879400.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13879400_visualized.jpg
# 처리 완료: 13854997.json 및 13854997.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13854997_visualized.jpg
# 처리 완료: 13868509.json 및 13868509.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13868509_visualized.jpg
# 처리 완료: 13919307.json 및 13919307.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13919307_visualized.jpg
# 처리 완료: 13819045.json 및 13819045.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13819045_visualized.jpg
# 처리 완료: 13737403.json 및 13737403.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13737403_visualized.jpg
# 처리 완료: 13882302.json 및 13882302.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13882302_visualized.jpg
# 처리 완료: 13749827.json 및 13749827.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13749827_visualized.jpg
# 처리 완료: 13672064.json 및 13672064.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13672064_visualized.jpg
# 처리 완료: 13868510.json 및 13868510.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13868510_visualized.jpg
# 처리 완료: 13687789.json 및 13687789.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13687789_visualized.jpg
# 처리 완료: 13737233.json 및 13737233.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13737233_visualized.jpg
# 처리 완료: 13658759.json 및 13658759.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13658759_visualized.jpg
# 처리 완료: 13687186.json 및 13687186.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13687186_visualized.jpg
# 처리 완료: 13840236.json 및 13840236.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13840236_visualized.jpg
# 처리 완료: 13850969.json 및 13850969.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13850969_visualized.jpg
# 처리 완료: 13726391.json 및 13726391.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13726391_visualized.jpg
# 처리 완료: 13658765.json 및 13658765.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13658765_visualized.jpg
# 처리 완료: 13931722.json 및 13931722.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13931722_visualized.jpg
# 처리 완료: 13840235.json 및 13840235.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13840235_visualized.jpg
# 처리 완료: 13840242.json 및 13840242.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13840242_visualized.jpg
# 처리 완료: 13735124.json 및 13735124.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13735124_visualized.jpg
# 처리 완료: 13746122.json 및 13746122.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13746122_visualized.jpg
# 처리 완료: 13720167.json 및 13720167.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13720167_visualized.jpg
# 처리 완료: 13853502.json 및 13853502.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13853502_visualized.jpg
# 처리 완료: 13945769.json 및 13945769.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13945769_visualized.jpg
# 처리 완료: 13738027.json 및 13738027.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13738027_visualized.jpg
# 처리 완료: 13868524.json 및 13868524.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13868524_visualized.jpg
# 처리 완료: 13815185.json 및 13815185.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13815185_visualized.jpg
# 처리 완료: 13658744.json 및 13658744.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13658744_visualized.jpg
# 처리 완료: 13846966.json 및 13846966.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13846966_visualized.jpg
# 처리 완료: 13990487.json 및 13990487.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13990487_visualized.jpg
# 처리 완료: 13849706.json 및 13849706.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13849706_visualized.jpg
# 처리 완료: 13819067.json 및 13819067.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13819067_visualized.jpg
# 처리 완료: 13647579.json 및 13647579.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13647579_visualized.jpg
# 처리 완료: 13815183.json 및 13815183.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13815183_visualized.jpg
# 처리 완료: 13815205.json 및 13815205.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13815205_visualized.jpg
# 처리 완료: 13840252.json 및 13840252.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13840252_visualized.jpg
# 처리 완료: 13952298.json 및 13952298.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13952298_visualized.jpg
# 처리 완료: 13978129.json 및 13978129.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13978129_visualized.jpg
# 처리 완료: 13819048.json 및 13819048.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13819048_visualized.jpg
# 처리 완료: 13647673.json 및 13647673.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13647673_visualized.jpg
# 처리 완료: 13726394.json 및 13726394.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13726394_visualized.jpg
# 처리 완료: 13850790.json 및 13850790.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13850790_visualized.jpg
# 처리 완료: 13676120.json 및 13676120.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13676120_visualized.jpg
# 처리 완료: 13986583.json 및 13986583.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13986583_visualized.jpg
# 처리 완료: 13720245.json 및 13720245.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13720245_visualized.jpg
# 처리 완료: 13840217.json 및 13840217.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13840217_visualized.jpg
# 처리 완료: 13692581.json 및 13692581.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13692581_visualized.jpg
# 처리 완료: 13866630.json 및 13866630.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13866630_visualized.jpg
# 처리 완료: 13676292.json 및 13676292.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13676292_visualized.jpg
# 처리 완료: 13850918.json 및 13850918.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13850918_visualized.jpg
# 처리 완료: 13879383.json 및 13879383.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13879383_visualized.jpg
# 처리 완료: 13868495.json 및 13868495.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13868495_visualized.jpg
# 처리 완료: 13840264.json 및 13840264.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13840264_visualized.jpg
# 처리 완료: 13750852.json 및 13750852.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13750852_visualized.jpg
# 처리 완료: 13700280.json 및 13700280.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13700280_visualized.jpg
# 처리 완료: 13680265.json 및 13680265.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13680265_visualized.jpg
# 처리 완료: 13908574.json 및 13908574.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13908574_visualized.jpg
# 처리 완료: 13647868.json 및 13647868.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13647868_visualized.jpg
# 처리 완료: 13687179.json 및 13687179.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13687179_visualized.jpg
# 처리 완료: 13813835.json 및 13813835.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13813835_visualized.jpg
# 처리 완료: 13838898.json 및 13838898.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13838898_visualized.jpg
# 처리 완료: 13950059.json 및 13950059.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13950059_visualized.jpg
# 처리 완료: 13672097.json 및 13672097.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13672097_visualized.jpg
# 처리 완료: 13849842.json 및 13849842.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13849842_visualized.jpg
# 처리 완료: 13815258.json 및 13815258.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13815258_visualized.jpg
# 처리 완료: 13818891.json 및 13818891.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13818891_visualized.jpg
# 처리 완료: 13868516.json 및 13868516.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13868516_visualized.jpg
# 처리 완료: 13849671.json 및 13849671.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13849671_visualized.jpg
# 처리 완료: 13879306.json 및 13879306.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13879306_visualized.jpg
# 처리 완료: 13658743.json 및 13658743.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13658743_visualized.jpg
# 처리 완료: 13676484.json 및 13676484.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13676484_visualized.jpg
# 처리 완료: 13668681.json 및 13668681.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13668681_visualized.jpg
# 처리 완료: 13735411.json 및 13735411.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13735411_visualized.jpg
# 처리 완료: 13868513.json 및 13868513.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13868513_visualized.jpg
# 처리 완료: 13720241.json 및 13720241.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13720241_visualized.jpg
# 처리 완료: 13868503.json 및 13868503.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13868503_visualized.jpg
# 처리 완료: 13879301.json 및 13879301.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13879301_visualized.jpg
# 처리 완료: 13676108.json 및 13676108.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13676108_visualized.jpg
# 처리 완료: 13658682.json 및 13658682.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13658682_visualized.jpg
# 처리 완료: 13868496.json 및 13868496.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13868496_visualized.jpg
# 처리 완료: 13838890.json 및 13838890.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13838890_visualized.jpg
# 처리 완료: 13868486.json 및 13868486.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13868486_visualized.jpg
# 처리 완료: 13672095.json 및 13672095.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13672095_visualized.jpg
# 처리 완료: 13815234.json 및 13815234.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13815234_visualized.jpg
# 처리 완료: 13849844.json 및 13849844.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13849844_visualized.jpg
# 처리 완료: 13931758.json 및 13931758.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13931758_visualized.jpg
# 처리 완료: 13676274.json 및 13676274.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13676274_visualized.jpg
# 처리 완료: 13658683.json 및 13658683.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13658683_visualized.jpg
# 처리 완료: 13679160.json 및 13679160.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13679160_visualized.jpg
# 처리 완료: 13952667.json 및 13952667.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13952667_visualized.jpg
# 처리 완료: 13840232.json 및 13840232.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13840232_visualized.jpg
# 처리 완료: 13746123.json 및 13746123.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13746123_visualized.jpg
# 처리 완료: 13819266.json 및 13819266.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13819266_visualized.jpg
# 처리 완료: 13815245.json 및 13815245.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13815245_visualized.jpg
# 처리 완료: 13819258.json 및 13819258.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13819258_visualized.jpg
# 처리 완료: 13849609.json 및 13849609.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13849609_visualized.jpg
# 처리 완료: 13840335.json 및 13840335.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13840335_visualized.jpg
# 처리 완료: 13840349.json 및 13840349.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13840349_visualized.jpg
# 처리 완료: 13784842.json 및 13784842.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13784842_visualized.jpg
# 처리 완료: 13931750.json 및 13931750.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13931750_visualized.jpg
# 처리 완료: 13818905.json 및 13818905.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13818905_visualized.jpg
# 처리 완료: 13850970.json 및 13850970.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13850970_visualized.jpg
# 처리 완료: 13846955.json 및 13846955.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13846955_visualized.jpg
# 처리 완료: 13826939.json 및 13826939.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13826939_visualized.jpg
# 처리 완료: 13737388.json 및 13737388.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13737388_visualized.jpg
# 처리 완료: 13846967.json 및 13846967.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13846967_visualized.jpg
# 처리 완료: 13819262.json 및 13819262.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13819262_visualized.jpg
# 처리 완료: 13931760.json 및 13931760.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13931760_visualized.jpg
# 처리 완료: 13676486.json 및 13676486.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13676486_visualized.jpg
# 처리 완료: 13720239.json 및 13720239.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13720239_visualized.jpg
# 처리 완료: 13815206.json 및 13815206.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13815206_visualized.jpg
# 처리 완료: 13647575.json 및 13647575.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13647575_visualized.jpg
# 처리 완료: 13669013.json 및 13669013.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13669013_visualized.jpg
# 처리 완료: 13647689.json 및 13647689.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13647689_visualized.jpg
# 처리 완료: 13737389.json 및 13737389.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13737389_visualized.jpg
# 처리 완료: 13931754.json 및 13931754.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13931754_visualized.jpg
# 처리 완료: 13672060.json 및 13672060.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13672060_visualized.jpg
# 처리 완료: 13850789.json 및 13850789.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13850789_visualized.jpg
# 처리 완료: 13868491.json 및 13868491.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13868491_visualized.jpg
# 처리 완료: 13826978.json 및 13826978.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13826978_visualized.jpg
# 처리 완료: 13737405.json 및 13737405.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13737405_visualized.jpg
# 처리 완료: 13688191.json 및 13688191.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13688191_visualized.jpg
# 처리 완료: 13840211.json 및 13840211.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13840211_visualized.jpg
# 처리 완료: 13815243.json 및 13815243.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13815243_visualized.jpg
# 처리 완료: 13815173.json 및 13815173.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13815173_visualized.jpg
# 처리 완료: 13726402.json 및 13726402.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13726402_visualized.jpg
# 처리 완료: 13749548.json 및 13749548.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13749548_visualized.jpg
# 처리 완료: 13840255.json 및 13840255.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13840255_visualized.jpg
# 처리 완료: 13849837.json 및 13849837.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13849837_visualized.jpg
# 처리 완료: 13908581.json 및 13908581.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13908581_visualized.jpg
# 처리 완료: 13672086.json 및 13672086.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13672086_visualized.jpg
# 처리 완료: 13749547.json 및 13749547.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13749547_visualized.jpg
# 처리 완료: 13676462.json 및 13676462.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13676462_visualized.jpg
# 처리 완료: 13840239.json 및 13840239.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13840239_visualized.jpg
# 처리 완료: 13720238.json 및 13720238.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13720238_visualized.jpg
# 처리 완료: 13849617.json 및 13849617.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13849617_visualized.jpg
# 처리 완료: 13720146.json 및 13720146.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13720146_visualized.jpg
# 처리 완료: 13849612.json 및 13849612.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13849612_visualized.jpg
# 처리 완료: 13737398.json 및 13737398.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13737398_visualized.jpg
# 처리 완료: 13720158.json 및 13720158.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13720158_visualized.jpg
# 처리 완료: 13805698.json 및 13805698.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13805698_visualized.jpg
# 처리 완료: 13849646.json 및 13849646.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13849646_visualized.jpg
# 처리 완료: 13720243.json 및 13720243.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13720243_visualized.jpg
# 처리 완료: 13805619.json 및 13805619.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13805619_visualized.jpg
# 처리 완료: 13669014.json 및 13669014.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13669014_visualized.jpg
# 처리 완료: 13647873.json 및 13647873.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13647873_visualized.jpg
# 처리 완료: 13976116.json 및 13976116.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13976116_visualized.jpg
# 처리 완료: 13647580.json 및 13647580.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13647580_visualized.jpg
# 처리 완료: 13746118.json 및 13746118.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13746118_visualized.jpg
# 처리 완료: 13849681.json 및 13849681.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13849681_visualized.jpg
# 처리 완료: 13815166.json 및 13815166.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13815166_visualized.jpg
# 처리 완료: 13931748.json 및 13931748.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13931748_visualized.jpg
# 처리 완료: 13710525.json 및 13710525.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13710525_visualized.jpg
# 처리 완료: 13679162.json 및 13679162.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13679162_visualized.jpg
# 처리 완료: 13647871.json 및 13647871.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13647871_visualized.jpg
# 처리 완료: 13908474.json 및 13908474.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13908474_visualized.jpg
# 처리 완료: 13700279.json 및 13700279.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13700279_visualized.jpg
# 처리 완료: 13840254.json 및 13840254.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13840254_visualized.jpg
# 처리 완료: 13854392.json 및 13854392.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13854392_visualized.jpg
# 처리 완료: 13805699.json 및 13805699.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13805699_visualized.jpg
# 처리 완료: 13688181.json 및 13688181.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13688181_visualized.jpg
# 처리 완료: 13955381.json 및 13955381.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13955381_visualized.jpg
# 처리 완료: 13868518.json 및 13868518.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13868518_visualized.jpg
# 처리 완료: 13692523.json 및 13692523.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13692523_visualized.jpg
# 처리 완료: 13819261.json 및 13819261.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13819261_visualized.jpg
# 처리 완료: 13672090.json 및 13672090.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13672090_visualized.jpg
# 처리 완료: 13846958.json 및 13846958.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13846958_visualized.jpg
# 처리 완료: 13679278.json 및 13679278.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13679278_visualized.jpg
# 처리 완료: 13676483.json 및 13676483.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13676483_visualized.jpg
# 처리 완료: 13687192.json 및 13687192.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13687192_visualized.jpg
# 처리 완료: 13868502.json 및 13868502.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13868502_visualized.jpg
# 처리 완료: 13990491.json 및 13990491.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13990491_visualized.jpg
# 처리 완료: 13826565.json 및 13826565.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13826565_visualized.jpg
# 처리 완료: 13990493.json 및 13990493.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13990493_visualized.jpg
# 처리 완료: 13879372.json 및 13879372.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13879372_visualized.jpg
# 처리 완료: 13819060.json 및 13819060.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13819060_visualized.jpg
# 처리 완료: 13688051.json 및 13688051.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13688051_visualized.jpg
# 처리 완료: 13909843.json 및 13909843.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13909843_visualized.jpg
# 처리 완료: 13950058.json 및 13950058.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13950058_visualized.jpg
# 처리 완료: 13931701.json 및 13931701.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13931701_visualized.jpg
# 처리 완료: 13738051.json 및 13738051.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13738051_visualized.jpg
# 처리 완료: 13990490.json 및 13990490.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13990490_visualized.jpg
# 처리 완료: 13846971.json 및 13846971.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13846971_visualized.jpg
# 처리 완료: 13866499.json 및 13866499.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13866499_visualized.jpg
# 처리 완료: 13976085.json 및 13976085.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13976085_visualized.jpg
# 처리 완료: 13818899.json 및 13818899.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13818899_visualized.jpg
# 처리 완료: 13737225.json 및 13737225.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13737225_visualized.jpg
# 처리 완료: 13819061.json 및 13819061.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13819061_visualized.jpg
# 처리 완료: 13868500.json 및 13868500.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13868500_visualized.jpg
# 처리 완료: 13647681.json 및 13647681.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13647681_visualized.jpg
# 처리 완료: 13732234.json 및 13732234.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13732234_visualized.jpg
# 처리 완료: 13735394.json 및 13735394.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13735394_visualized.jpg
# 처리 완료: 13688193.json 및 13688193.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13688193_visualized.jpg
# 처리 완료: 13710539.json 및 13710539.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13710539_visualized.jpg
# 처리 완료: 13819044.json 및 13819044.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13819044_visualized.jpg
# 처리 완료: 13950126.json 및 13950126.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13950126_visualized.jpg
# 처리 완료: 13647578.json 및 13647578.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13647578_visualized.jpg
# 처리 완료: 13668719.json 및 13668719.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13668719_visualized.jpg
# 처리 완료: 13815156.json 및 13815156.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13815156_visualized.jpg
# 처리 완료: 13838875.json 및 13838875.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13838875_visualized.jpg
# 처리 완료: 13758948.json 및 13758948.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13758948_visualized.jpg
# 처리 완료: 13846969.json 및 13846969.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13846969_visualized.jpg
# 처리 완료: 13850960.json 및 13850960.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13850960_visualized.jpg
# 처리 완료: 13853504.json 및 13853504.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13853504_visualized.jpg
# 처리 완료: 13805653.json 및 13805653.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13805653_visualized.jpg
# 처리 완료: 13931710.json 및 13931710.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13931710_visualized.jpg
# 처리 완료: 13692447.json 및 13692447.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13692447_visualized.jpg
# 처리 완료: 13849632.json 및 13849632.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13849632_visualized.jpg
# 처리 완료: 13868444.json 및 13868444.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13868444_visualized.jpg
# 처리 완료: 13672098.json 및 13672098.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13672098_visualized.jpg
# 처리 완료: 13931712.json 및 13931712.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13931712_visualized.jpg
# 처리 완료: 13950025.json 및 13950025.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13950025_visualized.jpg
# 처리 완료: 13735371.json 및 13735371.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13735371_visualized.jpg
# 처리 완료: 13931741.json 및 13931741.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13931741_visualized.jpg
# 처리 완료: 13815216.json 및 13815216.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13815216_visualized.jpg
# 처리 완료: 13692571.json 및 13692571.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13692571_visualized.jpg
# 처리 완료: 13815244.json 및 13815244.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13815244_visualized.jpg
# 처리 완료: 13688053.json 및 13688053.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13688053_visualized.jpg
# 처리 완료: 13853508.json 및 13853508.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13853508_visualized.jpg
# 처리 완료: 13672059.json 및 13672059.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13672059_visualized.jpg
# 처리 완료: 13738028.json 및 13738028.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13738028_visualized.jpg
# 처리 완료: 13931706.json 및 13931706.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13931706_visualized.jpg
# 처리 완료: 13850793.json 및 13850793.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13850793_visualized.jpg
# 처리 완료: 13647848.json 및 13647848.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13647848_visualized.jpg
# 처리 완료: 13815176.json 및 13815176.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13815176_visualized.jpg
# 처리 완료: 13818904.json 및 13818904.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13818904_visualized.jpg
# 처리 완료: 13849840.json 및 13849840.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13849840_visualized.jpg
# 처리 완료: 13840249.json 및 13840249.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13840249_visualized.jpg
# 처리 완료: 13849704.json 및 13849704.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13849704_visualized.jpg
# 처리 완료: 13672092.json 및 13672092.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13672092_visualized.jpg
# 처리 완료: 13658782.json 및 13658782.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13658782_visualized.jpg
# 처리 완료: 13692533.json 및 13692533.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13692533_visualized.jpg
# 처리 완료: 13849697.json 및 13849697.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13849697_visualized.jpg
# 처리 완료: 13819255.json 및 13819255.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13819255_visualized.jpg
# 처리 완료: 13826926.json 및 13826926.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13826926_visualized.jpg
# 처리 완료: 13840261.json 및 13840261.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13840261_visualized.jpg
# 처리 완료: 13818912.json 및 13818912.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13818912_visualized.jpg
# 처리 완료: 13688183.json 및 13688183.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13688183_visualized.jpg
# 처리 완료: 13846964.json 및 13846964.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13846964_visualized.jpg
# 처리 완료: 13868517.json 및 13868517.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13868517_visualized.jpg
# 처리 완료: 13672087.json 및 13672087.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13672087_visualized.jpg
# 처리 완료: 13908560.json 및 13908560.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13908560_visualized.jpg
# 처리 완료: 13746158.json 및 13746158.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13746158_visualized.jpg
# 처리 완료: 13737404.json 및 13737404.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13737404_visualized.jpg
# 처리 완료: 13813839.json 및 13813839.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13813839_visualized.jpg
# 처리 완료: 13819049.json 및 13819049.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13819049_visualized.jpg
# 처리 완료: 13647678.json 및 13647678.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13647678_visualized.jpg
# 처리 완료: 13846957.json 및 13846957.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13846957_visualized.jpg
# 처리 완료: 13737226.json 및 13737226.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13737226_visualized.jpg
# 처리 완료: 13882257.json 및 13882257.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13882257_visualized.jpg
# 처리 완료: 13984564.json 및 13984564.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13984564_visualized.jpg
# 처리 완료: 13676463.json 및 13676463.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13676463_visualized.jpg
# 처리 완료: 13879399.json 및 13879399.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13879399_visualized.jpg
# 처리 완료: 13746141.json 및 13746141.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13746141_visualized.jpg
# 처리 완료: 13692573.json 및 13692573.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13692573_visualized.jpg
# 처리 완료: 13952689.json 및 13952689.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13952689_visualized.jpg
# 처리 완료: 13784880.json 및 13784880.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13784880_visualized.jpg
# 처리 완료: 13931713.json 및 13931713.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13931713_visualized.jpg
# 처리 완료: 13784834.json 및 13784834.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13784834_visualized.jpg
# 처리 완료: 13846392.json 및 13846392.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13846392_visualized.jpg
# 처리 완료: 13737391.json 및 13737391.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13737391_visualized.jpg
# 처리 완료: 13853510.json 및 13853510.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13853510_visualized.jpg
# 처리 완료: 13784878.json 및 13784878.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13784878_visualized.jpg
# 처리 완료: 13846961.json 및 13846961.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13846961_visualized.jpg
# 처리 완료: 13647577.json 및 13647577.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13647577_visualized.jpg
# 처리 완료: 13815184.json 및 13815184.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13815184_visualized.jpg
# 처리 완료: 13849668.json 및 13849668.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13849668_visualized.jpg
# 처리 완료: 13866528.json 및 13866528.jpg
# ...
# 처리 완료: 13680460.json 및 13680460.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13680460_visualized.jpg
# 처리 완료: 13868461.json 및 13868461.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13868461_visualized.jpg
# 처리 완료: 13813743.json 및 13813743.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13813743_visualized.jpg
# 처리 완료: 13729463.json 및 13729463.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13729463_visualized.jpg
# 처리 완료: 13805711.json 및 13805711.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13805711_visualized.jpg
# 처리 완료: 13950050.json 및 13950050.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13950050_visualized.jpg
# 처리 완료: 13729449.json 및 13729449.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13729449_visualized.jpg
# 처리 완료: 13784881.json 및 13784881.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13784881_visualized.jpg
# 처리 완료: 13990460.json 및 13990460.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13990460_visualized.jpg
# 처리 완료: 13813844.json 및 13813844.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13813844_visualized.jpg
# 처리 완료: 13850760.json 및 13850760.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13850760_visualized.jpg
# 처리 완료: 13932011.json 및 13932011.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13932011_visualized.jpg
# 처리 완료: 13950146.json 및 13950146.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13950146_visualized.jpg
# 처리 완료: 13742393.json 및 13742393.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13742393_visualized.jpg
# 처리 완료: 13723978.json 및 13723978.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13723978_visualized.jpg
# 처리 완료: 13950031.json 및 13950031.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13950031_visualized.jpg
# 처리 완료: 13805644.json 및 13805644.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13805644_visualized.jpg
# 처리 완료: 13805691.json 및 13805691.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13805691_visualized.jpg
# 처리 완료: 13855035.json 및 13855035.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13855035_visualized.jpg
# 처리 완료: 13950069.json 및 13950069.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13950069_visualized.jpg
# 처리 완료: 13805614.json 및 13805614.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13805614_visualized.jpg
# 처리 완료: 13798188.json 및 13798188.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13798188_visualized.jpg
# 처리 완료: 13951482.json 및 13951482.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13951482_visualized.jpg
# 처리 완료: 13805635.json 및 13805635.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13805635_visualized.jpg
# 처리 완료: 13918393.json 및 13918393.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13918393_visualized.jpg
# 처리 완료: 13976056.json 및 13976056.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13976056_visualized.jpg
# 처리 완료: 13813842.json 및 13813842.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13813842_visualized.jpg
# 처리 완료: 13692431.json 및 13692431.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13692431_visualized.jpg
# 처리 완료: 13918398.json 및 13918398.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13918398_visualized.jpg
# 처리 완료: 13658729.json 및 13658729.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13658729_visualized.jpg
# 처리 완료: 13849621.json 및 13849621.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13849621_visualized.jpg
# 처리 완료: 13882307.json 및 13882307.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13882307_visualized.jpg
# 처리 완료: 13680431.json 및 13680431.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13680431_visualized.jpg
# 처리 완료: 13918040.json 및 13918040.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13918040_visualized.jpg
# 처리 완료: 13868476.json 및 13868476.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13868476_visualized.jpg
# 처리 완료: 13742100.json 및 13742100.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13742100_visualized.jpg
# 처리 완료: 13989764.json 및 13989764.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13989764_visualized.jpg
# 처리 완료: 13882260.json 및 13882260.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13882260_visualized.jpg
# 처리 완료: 13932012.json 및 13932012.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13932012_visualized.jpg
# 처리 완료: 13680452.json 및 13680452.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13680452_visualized.jpg
# 처리 완료: 13950015.json 및 13950015.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13950015_visualized.jpg
# 처리 완료: 13945699.json 및 13945699.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13945699_visualized.jpg
# 처리 완료: 13680768.json 및 13680768.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13680768_visualized.jpg
# 처리 완료: 13882294.json 및 13882294.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13882294_visualized.jpg
# 처리 완료: 13784856.json 및 13784856.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13784856_visualized.jpg
# 처리 완료: 13952680.json 및 13952680.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13952680_visualized.jpg
# 처리 완료: 13945692.json 및 13945692.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13945692_visualized.jpg
# 처리 완료: 13945873.json 및 13945873.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13945873_visualized.jpg
# 처리 완료: 13951493.json 및 13951493.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13951493_visualized.jpg
# 처리 완료: 13716198.json 및 13716198.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13716198_visualized.jpg
# 처리 완료: 13784811.json 및 13784811.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13784811_visualized.jpg
# 처리 완료: 13949984.json 및 13949984.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13949984_visualized.jpg
# 처리 완료: 13658667.json 및 13658667.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13658667_visualized.jpg
# 처리 완료: 13952291.json 및 13952291.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13952291_visualized.jpg
# 처리 완료: 13855055.json 및 13855055.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13855055_visualized.jpg
# 처리 완료: 13784813.json 및 13784813.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13784813_visualized.jpg
# 처리 완료: 13952281.json 및 13952281.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13952281_visualized.jpg
# 처리 완료: 13866581.json 및 13866581.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13866581_visualized.jpg
# 처리 완료: 13750832.json 및 13750832.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13750832_visualized.jpg
# 처리 완료: 13742093.json 및 13742093.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13742093_visualized.jpg
# 처리 완료: 13918394.json 및 13918394.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13918394_visualized.jpg
# 처리 완료: 13742348.json 및 13742348.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13742348_visualized.jpg
# 처리 완료: 13952658.json 및 13952658.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13952658_visualized.jpg
# 처리 완료: 13931711.json 및 13931711.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13931711_visualized.jpg
# 처리 완료: 13882301.json 및 13882301.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13882301_visualized.jpg
# 처리 완료: 13784530.json 및 13784530.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13784530_visualized.jpg
# 처리 완료: 13735424.json 및 13735424.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13735424_visualized.jpg
# 처리 완료: 13849636.json 및 13849636.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13849636_visualized.jpg
# 처리 완료: 13680456.json 및 13680456.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13680456_visualized.jpg
# 처리 완료: 13976084.json 및 13976084.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13976084_visualized.jpg
# 처리 완료: 13918034.json 및 13918034.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13918034_visualized.jpg
# 처리 완료: 13850974.json 및 13850974.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13850974_visualized.jpg
# 처리 완료: 13976068.json 및 13976068.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13976068_visualized.jpg
# 처리 완료: 13658678.json 및 13658678.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13658678_visualized.jpg
# 처리 완료: 13952655.json 및 13952655.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13952655_visualized.jpg
# 처리 완료: 13749537.json 및 13749537.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13749537_visualized.jpg
# 처리 완료: 13882412.json 및 13882412.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13882412_visualized.jpg
# 처리 완료: 13950032.json 및 13950032.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13950032_visualized.jpg
# 처리 완료: 13692455.json 및 13692455.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13692455_visualized.jpg
# 처리 완료: 13668698.json 및 13668698.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13668698_visualized.jpg
# 처리 완료: 13918406.json 및 13918406.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13918406_visualized.jpg
# 처리 완료: 13949983.json 및 13949983.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13949983_visualized.jpg
# 처리 완료: 13784896.json 및 13784896.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13784896_visualized.jpg
# 처리 완료: 13784820.json 및 13784820.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13784820_visualized.jpg
# 처리 완료: 13945768.json 및 13945768.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13945768_visualized.jpg
# 처리 완료: 13680457.json 및 13680457.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13680457_visualized.jpg
# 처리 완료: 13805649.json 및 13805649.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13805649_visualized.jpg
# 처리 완료: 13850975.json 및 13850975.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13850975_visualized.jpg
# 처리 완료: 13713744.json 및 13713744.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13713744_visualized.jpg
# 처리 완료: 13798178.json 및 13798178.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13798178_visualized.jpg
# 처리 완료: 13950016.json 및 13950016.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13950016_visualized.jpg
# 처리 완료: 13742379.json 및 13742379.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13742379_visualized.jpg
# 처리 완료: 13726414.json 및 13726414.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13726414_visualized.jpg
# 처리 완료: 13945774.json 및 13945774.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13945774_visualized.jpg
# 처리 완료: 13784872.json 및 13784872.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13784872_visualized.jpg
# 처리 완료: 13882411.json 및 13882411.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13882411_visualized.jpg
# 처리 완료: 13952686.json 및 13952686.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13952686_visualized.jpg
# 처리 완료: 13990483.json 및 13990483.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13990483_visualized.jpg
# 처리 완료: 13952684.json 및 13952684.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13952684_visualized.jpg
# 처리 완료: 13950131.json 및 13950131.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13950131_visualized.jpg
# 처리 완료: 13805674.json 및 13805674.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13805674_visualized.jpg
# 처리 완료: 13669029.json 및 13669029.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13669029_visualized.jpg
# 처리 완료: 13854400.json 및 13854400.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13854400_visualized.jpg
# 처리 완료: 13679184.json 및 13679184.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13679184_visualized.jpg
# 처리 완료: 13680278.json 및 13680278.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13680278_visualized.jpg
# 처리 완료: 13945721.json 및 13945721.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13945721_visualized.jpg
# 처리 완료: 13945730.json 및 13945730.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13945730_visualized.jpg
# 처리 완료: 13882410.json 및 13882410.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13882410_visualized.jpg
# 처리 완료: 13735493.json 및 13735493.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13735493_visualized.jpg
# 처리 완료: 13882266.json 및 13882266.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13882266_visualized.jpg
# 처리 완료: 13668696.json 및 13668696.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13668696_visualized.jpg
# 처리 완료: 13868533.json 및 13868533.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13868533_visualized.jpg
# 처리 완료: 13950147.json 및 13950147.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13950147_visualized.jpg
# 처리 완료: 13952706.json 및 13952706.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13952706_visualized.jpg
# 처리 완료: 13669030.json 및 13669030.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13669030_visualized.jpg
# 처리 완료: 13658737.json 및 13658737.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13658737_visualized.jpg
# 처리 완료: 13750845.json 및 13750845.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13750845_visualized.jpg
# 처리 완료: 13945715.json 및 13945715.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13945715_visualized.jpg
# 처리 완료: 13849682.json 및 13849682.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13849682_visualized.jpg
# 처리 완료: 13798181.json 및 13798181.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13798181_visualized.jpg
# 처리 완료: 13932027.json 및 13932027.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13932027_visualized.jpg
# 처리 완료: 13742097.json 및 13742097.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13742097_visualized.jpg
# 처리 완료: 13658734.json 및 13658734.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13658734_visualized.jpg
# 처리 완료: 13742353.json 및 13742353.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13742353_visualized.jpg
# 처리 완료: 13866586.json 및 13866586.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13866586_visualized.jpg
# 처리 완료: 13849694.json 및 13849694.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13849694_visualized.jpg
# 처리 완료: 13713746.json 및 13713746.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13713746_visualized.jpg
# 처리 완료: 13882310.json 및 13882310.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13882310_visualized.jpg
# 처리 완료: 13798169.json 및 13798169.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13798169_visualized.jpg
# 처리 완료: 13692436.json 및 13692436.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13692436_visualized.jpg
# 처리 완료: 13976077.json 및 13976077.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13976077_visualized.jpg
# 처리 완료: 13949985.json 및 13949985.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13949985_visualized.jpg
# 처리 완료: 13658762.json 및 13658762.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13658762_visualized.jpg
# 처리 완료: 13952671.json 및 13952671.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13952671_visualized.jpg
# 처리 완료: 13750847.json 및 13750847.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13750847_visualized.jpg
# 처리 완료: 13945853.json 및 13945853.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13945853_visualized.jpg
# 처리 완료: 13712594.json 및 13712594.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13712594_visualized.jpg
# 처리 완료: 13854408.json 및 13854408.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13854408_visualized.jpg
# 처리 완료: 13729457.json 및 13729457.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13729457_visualized.jpg
# 처리 완료: 13952284.json 및 13952284.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13952284_visualized.jpg
# 처리 완료: 13713742.json 및 13713742.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13713742_visualized.jpg
# 처리 완료: 13854385.json 및 13854385.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13854385_visualized.jpg
# 처리 완료: 13813667.json 및 13813667.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13813667_visualized.jpg
# 처리 완료: 13949987.json 및 13949987.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13949987_visualized.jpg
# 처리 완료: 13882331.json 및 13882331.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13882331_visualized.jpg
# 처리 완료: 13742360.json 및 13742360.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13742360_visualized.jpg
# 처리 완료: 13868537.json 및 13868537.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13868537_visualized.jpg
# 처리 완료: 13742350.json 및 13742350.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13742350_visualized.jpg
# 처리 완료: 13798173.json 및 13798173.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13798173_visualized.jpg
# 처리 완료: 13742356.json 및 13742356.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13742356_visualized.jpg
# 처리 완료: 13990461.json 및 13990461.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13990461_visualized.jpg
# 처리 완료: 13742341.json 및 13742341.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13742341_visualized.jpg
# 처리 완료: 13990502.json 및 13990502.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13990502_visualized.jpg
# 처리 완료: 13945738.json 및 13945738.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13945738_visualized.jpg
# 처리 완료: 13805707.json 및 13805707.jpg
# 시각화 결과: /content/drive/MyDrive/output_jpg/13805707_visualized.jpg
# YOLO 형식 레이블이 /content/drive/MyDrive/labels 디렉토리에 생성되었습니다.
# 시각화 결과가 /content/drive/MyDrive/output_jpg 디렉토리에 저장되었습니다.
# YAML 파일이 생성되었습니다: traffic_light_dataset.yaml
